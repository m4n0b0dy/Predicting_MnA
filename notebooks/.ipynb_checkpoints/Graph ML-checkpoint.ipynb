# %%
import sys
sys.path.insert(0, '../')
from utils.GraphAnalytics import GraphAnalytics
from models.Node2Vec import GraphNode2Vec
import numpy as np
import pandas as pd

# %%
g = GraphAnalytics()
g.load_graph('../data/full_graph')

# %% [raw]
# mod = GraphNode2Vec(walk_length = 8, workers = -1)
# mod.fit(g.as_undigraph)
# em_df = pd.DataFrame(mod.embeddings).transpose()
# em_df.to_csv('../data/wl_8_full_embeddings.csv', index=False)

# %%
em_4_df = pd.read_csv('../data/wl_4_full_embeddings.csv')
em_8_df = pd.read_csv('../data/wl_8_full_embeddings.csv')

# %%
mod = GraphNode2Vec(walk_length = 1, workers = -1)#basic embedding, nodes are missing from the 8 length walk
mod.fit(g.as_undigraph)
final_embeddings = mod.embeddings.copy()
final_embeddings.update(dict(zip(em_4_df.index, em_4_df.values)))
final_embeddings.update(dict(zip(em_8_df.index, em_8_df.values)))# combine and overwrite for 8 length walk

# %% [markdown]
# ### StellarGraph implementation
#
# https://stellargraph.readthedocs.io/en/stable/demos/link-prediction/hinsage-link-prediction.html

# %%
from stellargraph.data import EdgeSplitter
from stellargraph import StellarGraph
from stellargraph.mapper import HinSAGELinkGenerator
from stellargraph.layer import HinSAGE, link_classification
from stellargraph.utils import plot_history
from tensorflow.keras import Model, optimizers, losses, metrics
from tensorflow import keras
from IPython.display import display, HTML
import matplotlib.pyplot as plt
import networkx as nx
# %matplotlib inline

# %%
#load in with original node2vec embeddings
st_g = g.as_undigraph.copy()
nx.set_node_attributes(
    st_g,
    final_embeddings,
    'node2vec_embeddings',
)
st_g = StellarGraph.from_networkx(st_g, node_features='node2vec_embeddings')
#print(st_g.info())

# %%
#the two really important hyper parameters are different in graph than traditional ML
#test_pred_target_edge_count determines how many of the target edges we drop to later use as test data to evaluate prediction accuracy
#the next cell block ALSO negativly samples nodes without the target edge and trains binary classification between the two node to node datasets
test_pred_target_edge_count = .3
#train_pred_target_edge_count is used to sub sample from the test graph, NOT the original graph
#train_pred_target_edge_count determines how many of the target edges we drop to use in training, aka finding optima via SGD and backprop
#we feed in the drop edges as training data, just like you would feed in labels with a feature set
train_pred_target_edge_count = 0.5
#However! There are still some target edges remaining in the graph. The amount is orig_graph_target_edges * test_pred_target_edge_count * train_pred_target_edge_count
#these remaining target edges are now FEATURES instead of labels. The G_train subgraph can use them in training it's edge prediction classification task
#confused me at first as it adds an additional element of splitting to traditional ML.
#IMO the main reason is that labels can be features. This especially important in time sries graphs, where you may know an acqusition had happened in the previous timestep
#then an LSTM would benefit from that prior state knowledge and make the right adjustment
org_target_count = len([_ for _ in st_g.edges(include_edge_type=True) if _[2]=='ACQUIRED'])
test_target_count = int(org_target_count*(1-test_pred_target_edge_count))
train_target_count = int(test_target_count*(1-train_pred_target_edge_count))

print('Original Target Edges',org_target_count)
print('Target Edges to be held in test dataset, unseen by training, and later used in evaluation', org_target_count-test_target_count)
print('Target Edges to be held in train dataset, used by backprop to opto', test_target_count-train_target_count)
print('Remaining Target Edges turned into features',train_target_count)
#when running the edgesplitter, the test edge splitter should be close to this number, and same with train
num_workers = -1
# Out:
# Original Target Edges 2985
# Target Edges to be held in test dataset, unseen by training, and later used in evaluation 896
# Target Edges to be held in train dataset, used by backprop to opto 1045
# Remaining Target Edges turned into features 1044

# %%
edge_splitter_test = EdgeSplitter(st_g)
G_test, edge_ids_test, edge_labels_test = edge_splitter_test.train_test_split(
    p=test_pred_target_edge_count, method="global", edge_label='ACQUIRED'
)
#setting keep connected as false because
#ValueError: Unable to sample 298 positive edges (could only sample 90 positive edges). Consider using smaller value for p or set keep_connected=False

#this produced edge_ids_test which is a subgraph of original, missing test_pred_target_edge_count of target edges
#and edge_labels_test which is a dataset if positive labels 1 (the acquired edge exists),
#and negative samples, the acquired edge doesn't exist 0
#can bassically run G_test as your training data
#can see when comparing info
# Out:
# Network has 2985 edges of type ACQUIRED
# Network has 2985 edges of type ACQUIRED
# ** Sampled 895 positive and 895 negative edges. **

# %%
edge_splitter_test = EdgeSplitter(G_test)
G_train, edge_ids_train, edge_labels_train = edge_splitter_test.train_test_split(
    p=train_pred_target_edge_count, method="global", edge_label='ACQUIRED'
)
# Out:
# Network has 2090 edges of type ACQUIRED
# Network has 2090 edges of type ACQUIRED
# ** Sampled 1045 positive and 1045 negative edges. **

# %%
print(edge_ids_test.shape, edge_labels_test.shape)
# Out:
# (1790, 2) (1790,)

# %%
print('Sanity check')
for _g in [st_g, G_test, G_train]:
    print(len([_ for _ in _g.edges(include_edge_type=True) if _[2]=='ACQUIRED']))
    #print(st_g.info())
# Out:
# Sanity check
# 2985
# 2090
# 1045

# %% [markdown]
# ### Creation of the model

# %%
batch_size = 500
epochs = 200
num_samples=[8,4]

# %% [markdown]
# ### Better Train Test Split Methadoloy
# https://stellargraph.readthedocs.io/en/stable/demos/link-prediction/graphsage-link-prediction.html

# %%
test_generator = HinSAGELinkGenerator(st_g, batch_size=batch_size,
                                      num_samples=num_samples,
                                      head_node_types=["Company", "Company"])
test_gen = test_generator.flow(edge_ids_test, edge_labels_test)

# %%
train_generator = HinSAGELinkGenerator(G_train, batch_size=batch_size,
                                       num_samples=num_samples,
                                       head_node_types=["Company", "Company"])
train_gen = train_generator.flow(edge_ids_train, edge_labels_train, shuffle=True)

# %%
hinsage_layer_sizes = [32,32]
assert len(hinsage_layer_sizes) == len(num_samples)

hinsage = HinSAGE(
    layer_sizes=hinsage_layer_sizes, generator=train_generator, bias=True, dropout=0.3
)
x_inp, x_out = hinsage.in_out_tensors()

# %%
prediction = link_classification(
    output_dim=1, output_act="relu", edge_embedding_method="ip"
)(x_out)
# Out:
# link_classification: using 'ip' method to combine node embeddings into edge embeddings

# %%
model = Model(inputs=x_inp, outputs=prediction)
model.compile(
    optimizer=keras.optimizers.Adam(lr=1e-3),
    loss=keras.losses.binary_crossentropy,
    metrics=['accuracy'],
)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 8, 128)]     0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 8, 128)]     0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            [(None, 8, 128)]     0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 8, 128)]     0
# __________________________________________________________________________________________________
# input_7 (InputLayer)            [(None, 8, 128)]     0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            [(None, 8, 128)]     0
# __________________________________________________________________________________________________
# input_9 (InputLayer)            [(None, 8, 128)]     0
# __________________________________________________________________________________________________
# input_10 (InputLayer)           [(None, 8, 128)]     0
# __________________________________________________________________________________________________
# input_11 (InputLayer)           [(None, 8, 128)]     0
# __________________________________________________________________________________________________
# input_12 (InputLayer)           [(None, 8, 128)]     0
# __________________________________________________________________________________________________
# input_13 (InputLayer)           [(None, 8, 128)]     0
# __________________________________________________________________________________________________
# input_14 (InputLayer)           [(None, 8, 128)]     0
# __________________________________________________________________________________________________
# input_15 (InputLayer)           [(None, 8, 128)]     0
# __________________________________________________________________________________________________
# input_29 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_30 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_31 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_32 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_33 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_34 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_35 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_36 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_37 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_38 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_39 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_40 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_41 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_42 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_43 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_44 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_45 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_46 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_47 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_48 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_49 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_50 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_51 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_52 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_53 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_54 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_55 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_56 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_57 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_58 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_59 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_60 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_61 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_62 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_63 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_64 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_65 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_66 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_67 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_68 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_69 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_70 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_71 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_72 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_73 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_74 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_75 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_76 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_77 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_16 (InputLayer)           [(None, 8, 128)]     0
# __________________________________________________________________________________________________
# input_17 (InputLayer)           [(None, 8, 128)]     0
# __________________________________________________________________________________________________
# input_18 (InputLayer)           [(None, 8, 128)]     0
# __________________________________________________________________________________________________
# input_19 (InputLayer)           [(None, 8, 128)]     0
# __________________________________________________________________________________________________
# input_20 (InputLayer)           [(None, 8, 128)]     0
# __________________________________________________________________________________________________
# input_21 (InputLayer)           [(None, 8, 128)]     0
# __________________________________________________________________________________________________
# input_22 (InputLayer)           [(None, 8, 128)]     0
# __________________________________________________________________________________________________
# input_23 (InputLayer)           [(None, 8, 128)]     0
# __________________________________________________________________________________________________
# input_24 (InputLayer)           [(None, 8, 128)]     0
# __________________________________________________________________________________________________
# input_25 (InputLayer)           [(None, 8, 128)]     0
# __________________________________________________________________________________________________
# input_26 (InputLayer)           [(None, 8, 128)]     0
# __________________________________________________________________________________________________
# input_27 (InputLayer)           [(None, 8, 128)]     0
# __________________________________________________________________________________________________
# input_28 (InputLayer)           [(None, 8, 128)]     0
# __________________________________________________________________________________________________
# input_78 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_79 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_80 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_81 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_82 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_83 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_84 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_85 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_86 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_87 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_88 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_89 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_90 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_91 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_92 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_93 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_94 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_95 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_96 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_97 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_98 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_99 (InputLayer)           [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_100 (InputLayer)          [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_101 (InputLayer)          [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_102 (InputLayer)          [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_103 (InputLayer)          [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_104 (InputLayer)          [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_105 (InputLayer)          [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_106 (InputLayer)          [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_107 (InputLayer)          [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_108 (InputLayer)          [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_109 (InputLayer)          [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_110 (InputLayer)          [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_111 (InputLayer)          [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_112 (InputLayer)          [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_113 (InputLayer)          [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_114 (InputLayer)          [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_115 (InputLayer)          [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_116 (InputLayer)          [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_117 (InputLayer)          [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_118 (InputLayer)          [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_119 (InputLayer)          [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_120 (InputLayer)          [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_121 (InputLayer)          [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_122 (InputLayer)          [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_123 (InputLayer)          [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_124 (InputLayer)          [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_125 (InputLayer)          [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_126 (InputLayer)          [(None, 32, 128)]    0
# __________________________________________________________________________________________________
# input_1 (InputLayer)            [(None, 1, 128)]     0
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1, 8, 128)    0           input_3[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 8, 128)    0           input_4[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 1, 8, 128)    0           input_5[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 1, 8, 128)    0           input_6[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 1, 8, 128)    0           input_7[0][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 1, 8, 128)    0           input_8[0][0]
# __________________________________________________________________________________________________
# reshape_6 (Reshape)             (None, 1, 8, 128)    0           input_9[0][0]
# __________________________________________________________________________________________________
# reshape_7 (Reshape)             (None, 1, 8, 128)    0           input_10[0][0]
# __________________________________________________________________________________________________
# reshape_8 (Reshape)             (None, 1, 8, 128)    0           input_11[0][0]
# __________________________________________________________________________________________________
# reshape_9 (Reshape)             (None, 1, 8, 128)    0           input_12[0][0]
# __________________________________________________________________________________________________
# reshape_10 (Reshape)            (None, 1, 8, 128)    0           input_13[0][0]
# __________________________________________________________________________________________________
# reshape_11 (Reshape)            (None, 1, 8, 128)    0           input_14[0][0]
# __________________________________________________________________________________________________
# reshape_12 (Reshape)            (None, 1, 8, 128)    0           input_15[0][0]
# __________________________________________________________________________________________________
# reshape_26 (Reshape)            (None, 8, 4, 128)    0           input_29[0][0]
# __________________________________________________________________________________________________
# reshape_27 (Reshape)            (None, 8, 4, 128)    0           input_30[0][0]
# __________________________________________________________________________________________________
# reshape_28 (Reshape)            (None, 8, 4, 128)    0           input_31[0][0]
# __________________________________________________________________________________________________
# reshape_29 (Reshape)            (None, 8, 4, 128)    0           input_32[0][0]
# __________________________________________________________________________________________________
# reshape_30 (Reshape)            (None, 8, 4, 128)    0           input_33[0][0]
# __________________________________________________________________________________________________
# reshape_31 (Reshape)            (None, 8, 4, 128)    0           input_34[0][0]
# __________________________________________________________________________________________________
# reshape_32 (Reshape)            (None, 8, 4, 128)    0           input_35[0][0]
# __________________________________________________________________________________________________
# reshape_33 (Reshape)            (None, 8, 4, 128)    0           input_36[0][0]
# __________________________________________________________________________________________________
# reshape_34 (Reshape)            (None, 8, 4, 128)    0           input_37[0][0]
# __________________________________________________________________________________________________
# reshape_35 (Reshape)            (None, 8, 4, 128)    0           input_38[0][0]
# __________________________________________________________________________________________________
# reshape_36 (Reshape)            (None, 8, 4, 128)    0           input_39[0][0]
# __________________________________________________________________________________________________
# reshape_37 (Reshape)            (None, 8, 4, 128)    0           input_40[0][0]
# __________________________________________________________________________________________________
# reshape_38 (Reshape)            (None, 8, 4, 128)    0           input_41[0][0]
# __________________________________________________________________________________________________
# reshape_39 (Reshape)            (None, 8, 4, 128)    0           input_42[0][0]
# __________________________________________________________________________________________________
# reshape_40 (Reshape)            (None, 8, 4, 128)    0           input_43[0][0]
# __________________________________________________________________________________________________
# reshape_41 (Reshape)            (None, 8, 4, 128)    0           input_44[0][0]
# __________________________________________________________________________________________________
# reshape_42 (Reshape)            (None, 8, 4, 128)    0           input_45[0][0]
# __________________________________________________________________________________________________
# reshape_43 (Reshape)            (None, 8, 4, 128)    0           input_46[0][0]
# __________________________________________________________________________________________________
# reshape_44 (Reshape)            (None, 8, 4, 128)    0           input_47[0][0]
# __________________________________________________________________________________________________
# reshape_45 (Reshape)            (None, 8, 4, 128)    0           input_48[0][0]
# __________________________________________________________________________________________________
# reshape_46 (Reshape)            (None, 8, 4, 128)    0           input_49[0][0]
# __________________________________________________________________________________________________
# reshape_47 (Reshape)            (None, 8, 4, 128)    0           input_50[0][0]
# __________________________________________________________________________________________________
# reshape_48 (Reshape)            (None, 8, 4, 128)    0           input_51[0][0]
# __________________________________________________________________________________________________
# reshape_49 (Reshape)            (None, 8, 4, 128)    0           input_52[0][0]
# __________________________________________________________________________________________________
# reshape_50 (Reshape)            (None, 8, 4, 128)    0           input_53[0][0]
# __________________________________________________________________________________________________
# reshape_51 (Reshape)            (None, 8, 4, 128)    0           input_54[0][0]
# __________________________________________________________________________________________________
# reshape_52 (Reshape)            (None, 8, 4, 128)    0           input_55[0][0]
# __________________________________________________________________________________________________
# reshape_53 (Reshape)            (None, 8, 4, 128)    0           input_56[0][0]
# __________________________________________________________________________________________________
# reshape_54 (Reshape)            (None, 8, 4, 128)    0           input_57[0][0]
# __________________________________________________________________________________________________
# reshape_55 (Reshape)            (None, 8, 4, 128)    0           input_58[0][0]
# __________________________________________________________________________________________________
# reshape_56 (Reshape)            (None, 8, 4, 128)    0           input_59[0][0]
# __________________________________________________________________________________________________
# reshape_57 (Reshape)            (None, 8, 4, 128)    0           input_60[0][0]
# __________________________________________________________________________________________________
# reshape_58 (Reshape)            (None, 8, 4, 128)    0           input_61[0][0]
# __________________________________________________________________________________________________
# reshape_59 (Reshape)            (None, 8, 4, 128)    0           input_62[0][0]
# __________________________________________________________________________________________________
# reshape_60 (Reshape)            (None, 8, 4, 128)    0           input_63[0][0]
# __________________________________________________________________________________________________
# reshape_61 (Reshape)            (None, 8, 4, 128)    0           input_64[0][0]
# __________________________________________________________________________________________________
# reshape_62 (Reshape)            (None, 8, 4, 128)    0           input_65[0][0]
# __________________________________________________________________________________________________
# reshape_63 (Reshape)            (None, 8, 4, 128)    0           input_66[0][0]
# __________________________________________________________________________________________________
# reshape_64 (Reshape)            (None, 8, 4, 128)    0           input_67[0][0]
# __________________________________________________________________________________________________
# reshape_65 (Reshape)            (None, 8, 4, 128)    0           input_68[0][0]
# __________________________________________________________________________________________________
# reshape_66 (Reshape)            (None, 8, 4, 128)    0           input_69[0][0]
# __________________________________________________________________________________________________
# reshape_67 (Reshape)            (None, 8, 4, 128)    0           input_70[0][0]
# __________________________________________________________________________________________________
# reshape_68 (Reshape)            (None, 8, 4, 128)    0           input_71[0][0]
# __________________________________________________________________________________________________
# reshape_69 (Reshape)            (None, 8, 4, 128)    0           input_72[0][0]
# __________________________________________________________________________________________________
# reshape_70 (Reshape)            (None, 8, 4, 128)    0           input_73[0][0]
# __________________________________________________________________________________________________
# reshape_71 (Reshape)            (None, 8, 4, 128)    0           input_74[0][0]
# __________________________________________________________________________________________________
# reshape_72 (Reshape)            (None, 8, 4, 128)    0           input_75[0][0]
# __________________________________________________________________________________________________
# reshape_73 (Reshape)            (None, 8, 4, 128)    0           input_76[0][0]
# __________________________________________________________________________________________________
# reshape_74 (Reshape)            (None, 8, 4, 128)    0           input_77[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 1, 128)]     0
# __________________________________________________________________________________________________
# reshape_13 (Reshape)            (None, 1, 8, 128)    0           input_16[0][0]
# __________________________________________________________________________________________________
# reshape_14 (Reshape)            (None, 1, 8, 128)    0           input_17[0][0]
# __________________________________________________________________________________________________
# reshape_15 (Reshape)            (None, 1, 8, 128)    0           input_18[0][0]
# __________________________________________________________________________________________________
# reshape_16 (Reshape)            (None, 1, 8, 128)    0           input_19[0][0]
# __________________________________________________________________________________________________
# reshape_17 (Reshape)            (None, 1, 8, 128)    0           input_20[0][0]
# __________________________________________________________________________________________________
# reshape_18 (Reshape)            (None, 1, 8, 128)    0           input_21[0][0]
# __________________________________________________________________________________________________
# reshape_19 (Reshape)            (None, 1, 8, 128)    0           input_22[0][0]
# __________________________________________________________________________________________________
# reshape_20 (Reshape)            (None, 1, 8, 128)    0           input_23[0][0]
# __________________________________________________________________________________________________
# reshape_21 (Reshape)            (None, 1, 8, 128)    0           input_24[0][0]
# __________________________________________________________________________________________________
# reshape_22 (Reshape)            (None, 1, 8, 128)    0           input_25[0][0]
# __________________________________________________________________________________________________
# reshape_23 (Reshape)            (None, 1, 8, 128)    0           input_26[0][0]
# __________________________________________________________________________________________________
# reshape_24 (Reshape)            (None, 1, 8, 128)    0           input_27[0][0]
# __________________________________________________________________________________________________
# reshape_25 (Reshape)            (None, 1, 8, 128)    0           input_28[0][0]
# __________________________________________________________________________________________________
# reshape_75 (Reshape)            (None, 8, 4, 128)    0           input_78[0][0]
# __________________________________________________________________________________________________
# reshape_76 (Reshape)            (None, 8, 4, 128)    0           input_79[0][0]
# __________________________________________________________________________________________________
# reshape_77 (Reshape)            (None, 8, 4, 128)    0           input_80[0][0]
# __________________________________________________________________________________________________
# reshape_78 (Reshape)            (None, 8, 4, 128)    0           input_81[0][0]
# __________________________________________________________________________________________________
# reshape_79 (Reshape)            (None, 8, 4, 128)    0           input_82[0][0]
# __________________________________________________________________________________________________
# reshape_80 (Reshape)            (None, 8, 4, 128)    0           input_83[0][0]
# __________________________________________________________________________________________________
# reshape_81 (Reshape)            (None, 8, 4, 128)    0           input_84[0][0]
# __________________________________________________________________________________________________
# reshape_82 (Reshape)            (None, 8, 4, 128)    0           input_85[0][0]
# __________________________________________________________________________________________________
# reshape_83 (Reshape)            (None, 8, 4, 128)    0           input_86[0][0]
# __________________________________________________________________________________________________
# reshape_84 (Reshape)            (None, 8, 4, 128)    0           input_87[0][0]
# __________________________________________________________________________________________________
# reshape_85 (Reshape)            (None, 8, 4, 128)    0           input_88[0][0]
# __________________________________________________________________________________________________
# reshape_86 (Reshape)            (None, 8, 4, 128)    0           input_89[0][0]
# __________________________________________________________________________________________________
# reshape_87 (Reshape)            (None, 8, 4, 128)    0           input_90[0][0]
# __________________________________________________________________________________________________
# reshape_88 (Reshape)            (None, 8, 4, 128)    0           input_91[0][0]
# __________________________________________________________________________________________________
# reshape_89 (Reshape)            (None, 8, 4, 128)    0           input_92[0][0]
# __________________________________________________________________________________________________
# reshape_90 (Reshape)            (None, 8, 4, 128)    0           input_93[0][0]
# __________________________________________________________________________________________________
# reshape_91 (Reshape)            (None, 8, 4, 128)    0           input_94[0][0]
# __________________________________________________________________________________________________
# reshape_92 (Reshape)            (None, 8, 4, 128)    0           input_95[0][0]
# __________________________________________________________________________________________________
# reshape_93 (Reshape)            (None, 8, 4, 128)    0           input_96[0][0]
# __________________________________________________________________________________________________
# reshape_94 (Reshape)            (None, 8, 4, 128)    0           input_97[0][0]
# __________________________________________________________________________________________________
# reshape_95 (Reshape)            (None, 8, 4, 128)    0           input_98[0][0]
# __________________________________________________________________________________________________
# reshape_96 (Reshape)            (None, 8, 4, 128)    0           input_99[0][0]
# __________________________________________________________________________________________________
# reshape_97 (Reshape)            (None, 8, 4, 128)    0           input_100[0][0]
# __________________________________________________________________________________________________
# reshape_98 (Reshape)            (None, 8, 4, 128)    0           input_101[0][0]
# __________________________________________________________________________________________________
# reshape_99 (Reshape)            (None, 8, 4, 128)    0           input_102[0][0]
# __________________________________________________________________________________________________
# reshape_100 (Reshape)           (None, 8, 4, 128)    0           input_103[0][0]
# __________________________________________________________________________________________________
# reshape_101 (Reshape)           (None, 8, 4, 128)    0           input_104[0][0]
# __________________________________________________________________________________________________
# reshape_102 (Reshape)           (None, 8, 4, 128)    0           input_105[0][0]
# __________________________________________________________________________________________________
# reshape_103 (Reshape)           (None, 8, 4, 128)    0           input_106[0][0]
# __________________________________________________________________________________________________
# reshape_104 (Reshape)           (None, 8, 4, 128)    0           input_107[0][0]
# __________________________________________________________________________________________________
# reshape_105 (Reshape)           (None, 8, 4, 128)    0           input_108[0][0]
# __________________________________________________________________________________________________
# reshape_106 (Reshape)           (None, 8, 4, 128)    0           input_109[0][0]
# __________________________________________________________________________________________________
# reshape_107 (Reshape)           (None, 8, 4, 128)    0           input_110[0][0]
# __________________________________________________________________________________________________
# reshape_108 (Reshape)           (None, 8, 4, 128)    0           input_111[0][0]
# __________________________________________________________________________________________________
# reshape_109 (Reshape)           (None, 8, 4, 128)    0           input_112[0][0]
# __________________________________________________________________________________________________
# reshape_110 (Reshape)           (None, 8, 4, 128)    0           input_113[0][0]
# __________________________________________________________________________________________________
# reshape_111 (Reshape)           (None, 8, 4, 128)    0           input_114[0][0]
# __________________________________________________________________________________________________
# reshape_112 (Reshape)           (None, 8, 4, 128)    0           input_115[0][0]
# __________________________________________________________________________________________________
# reshape_113 (Reshape)           (None, 8, 4, 128)    0           input_116[0][0]
# __________________________________________________________________________________________________
# reshape_114 (Reshape)           (None, 8, 4, 128)    0           input_117[0][0]
# ...
#                                                                  dropout_134[0][0]
#                                                                  dropout_133[0][0]
# __________________________________________________________________________________________________
# mean_hin_aggregator_6 (MeanHinA (None, 8, 32)        4128        dropout_89[0][0]
#                                                                  dropout_88[0][0]
#                                                                  dropout_151[0][0]
#                                                                  dropout_150[0][0]
# __________________________________________________________________________________________________
# reshape_124 (Reshape)           (None, 1, 8, 32)     0           mean_hin_aggregator[2][0]
# __________________________________________________________________________________________________
# reshape_125 (Reshape)           (None, 1, 8, 32)     0           mean_hin_aggregator_1[0][0]
# __________________________________________________________________________________________________
# reshape_126 (Reshape)           (None, 1, 8, 32)     0           mean_hin_aggregator_2[0][0]
# __________________________________________________________________________________________________
# reshape_127 (Reshape)           (None, 1, 8, 32)     0           mean_hin_aggregator_2[1][0]
# __________________________________________________________________________________________________
# reshape_128 (Reshape)           (None, 1, 8, 32)     0           mean_hin_aggregator_1[1][0]
# __________________________________________________________________________________________________
# reshape_129 (Reshape)           (None, 1, 8, 32)     0           mean_hin_aggregator_1[2][0]
# __________________________________________________________________________________________________
# reshape_130 (Reshape)           (None, 1, 8, 32)     0           mean_hin_aggregator_3[0][0]
# __________________________________________________________________________________________________
# reshape_131 (Reshape)           (None, 1, 8, 32)     0           mean_hin_aggregator_4[0][0]
# __________________________________________________________________________________________________
# reshape_132 (Reshape)           (None, 1, 8, 32)     0           mean_hin_aggregator_5[0][0]
# __________________________________________________________________________________________________
# reshape_133 (Reshape)           (None, 1, 8, 32)     0           mean_hin_aggregator_1[3][0]
# __________________________________________________________________________________________________
# reshape_134 (Reshape)           (None, 1, 8, 32)     0           mean_hin_aggregator_1[4][0]
# __________________________________________________________________________________________________
# reshape_135 (Reshape)           (None, 1, 8, 32)     0           mean_hin_aggregator_4[1][0]
# __________________________________________________________________________________________________
# reshape_136 (Reshape)           (None, 1, 8, 32)     0           mean_hin_aggregator_6[0][0]
# __________________________________________________________________________________________________
# reshape_137 (Reshape)           (None, 1, 8, 32)     0           mean_hin_aggregator[3][0]
# __________________________________________________________________________________________________
# reshape_138 (Reshape)           (None, 1, 8, 32)     0           mean_hin_aggregator_1[5][0]
# __________________________________________________________________________________________________
# reshape_139 (Reshape)           (None, 1, 8, 32)     0           mean_hin_aggregator_2[2][0]
# __________________________________________________________________________________________________
# reshape_140 (Reshape)           (None, 1, 8, 32)     0           mean_hin_aggregator_2[3][0]
# __________________________________________________________________________________________________
# reshape_141 (Reshape)           (None, 1, 8, 32)     0           mean_hin_aggregator_1[6][0]
# __________________________________________________________________________________________________
# reshape_142 (Reshape)           (None, 1, 8, 32)     0           mean_hin_aggregator_1[7][0]
# __________________________________________________________________________________________________
# reshape_143 (Reshape)           (None, 1, 8, 32)     0           mean_hin_aggregator_3[1][0]
# __________________________________________________________________________________________________
# reshape_144 (Reshape)           (None, 1, 8, 32)     0           mean_hin_aggregator_4[2][0]
# __________________________________________________________________________________________________
# reshape_145 (Reshape)           (None, 1, 8, 32)     0           mean_hin_aggregator_5[1][0]
# __________________________________________________________________________________________________
# reshape_146 (Reshape)           (None, 1, 8, 32)     0           mean_hin_aggregator_1[8][0]
# __________________________________________________________________________________________________
# reshape_147 (Reshape)           (None, 1, 8, 32)     0           mean_hin_aggregator_1[9][0]
# __________________________________________________________________________________________________
# reshape_148 (Reshape)           (None, 1, 8, 32)     0           mean_hin_aggregator_4[3][0]
# __________________________________________________________________________________________________
# reshape_149 (Reshape)           (None, 1, 8, 32)     0           mean_hin_aggregator_6[1][0]
# __________________________________________________________________________________________________
# dropout_165 (Dropout)           (None, 1, 32)        0           mean_hin_aggregator[0][0]
# __________________________________________________________________________________________________
# dropout_152 (Dropout)           (None, 1, 8, 32)     0           reshape_124[0][0]
# __________________________________________________________________________________________________
# dropout_153 (Dropout)           (None, 1, 8, 32)     0           reshape_125[0][0]
# __________________________________________________________________________________________________
# dropout_154 (Dropout)           (None, 1, 8, 32)     0           reshape_126[0][0]
# __________________________________________________________________________________________________
# dropout_155 (Dropout)           (None, 1, 8, 32)     0           reshape_127[0][0]
# __________________________________________________________________________________________________
# dropout_156 (Dropout)           (None, 1, 8, 32)     0           reshape_128[0][0]
# __________________________________________________________________________________________________
# dropout_157 (Dropout)           (None, 1, 8, 32)     0           reshape_129[0][0]
# __________________________________________________________________________________________________
# dropout_158 (Dropout)           (None, 1, 8, 32)     0           reshape_130[0][0]
# __________________________________________________________________________________________________
# dropout_159 (Dropout)           (None, 1, 8, 32)     0           reshape_131[0][0]
# __________________________________________________________________________________________________
# dropout_160 (Dropout)           (None, 1, 8, 32)     0           reshape_132[0][0]
# __________________________________________________________________________________________________
# dropout_161 (Dropout)           (None, 1, 8, 32)     0           reshape_133[0][0]
# __________________________________________________________________________________________________
# dropout_162 (Dropout)           (None, 1, 8, 32)     0           reshape_134[0][0]
# __________________________________________________________________________________________________
# dropout_163 (Dropout)           (None, 1, 8, 32)     0           reshape_135[0][0]
# __________________________________________________________________________________________________
# dropout_164 (Dropout)           (None, 1, 8, 32)     0           reshape_136[0][0]
# __________________________________________________________________________________________________
# dropout_179 (Dropout)           (None, 1, 32)        0           mean_hin_aggregator[1][0]
# __________________________________________________________________________________________________
# dropout_166 (Dropout)           (None, 1, 8, 32)     0           reshape_137[0][0]
# __________________________________________________________________________________________________
# dropout_167 (Dropout)           (None, 1, 8, 32)     0           reshape_138[0][0]
# __________________________________________________________________________________________________
# dropout_168 (Dropout)           (None, 1, 8, 32)     0           reshape_139[0][0]
# __________________________________________________________________________________________________
# dropout_169 (Dropout)           (None, 1, 8, 32)     0           reshape_140[0][0]
# __________________________________________________________________________________________________
# dropout_170 (Dropout)           (None, 1, 8, 32)     0           reshape_141[0][0]
# __________________________________________________________________________________________________
# dropout_171 (Dropout)           (None, 1, 8, 32)     0           reshape_142[0][0]
# __________________________________________________________________________________________________
# dropout_172 (Dropout)           (None, 1, 8, 32)     0           reshape_143[0][0]
# __________________________________________________________________________________________________
# dropout_173 (Dropout)           (None, 1, 8, 32)     0           reshape_144[0][0]
# __________________________________________________________________________________________________
# dropout_174 (Dropout)           (None, 1, 8, 32)     0           reshape_145[0][0]
# __________________________________________________________________________________________________
# dropout_175 (Dropout)           (None, 1, 8, 32)     0           reshape_146[0][0]
# __________________________________________________________________________________________________
# dropout_176 (Dropout)           (None, 1, 8, 32)     0           reshape_147[0][0]
# __________________________________________________________________________________________________
# dropout_177 (Dropout)           (None, 1, 8, 32)     0           reshape_148[0][0]
# __________________________________________________________________________________________________
# dropout_178 (Dropout)           (None, 1, 8, 32)     0           reshape_149[0][0]
# __________________________________________________________________________________________________
# mean_hin_aggregator_7 (MeanHinA (None, 1, 32)        7200        dropout_165[0][0]
#                                                                  dropout_152[0][0]
#                                                                  dropout_153[0][0]
#                                                                  dropout_154[0][0]
#                                                                  dropout_155[0][0]
#                                                                  dropout_156[0][0]
#                                                                  dropout_157[0][0]
#                                                                  dropout_158[0][0]
#                                                                  dropout_159[0][0]
#                                                                  dropout_160[0][0]
#                                                                  dropout_161[0][0]
#                                                                  dropout_162[0][0]
#                                                                  dropout_163[0][0]
#                                                                  dropout_164[0][0]
#                                                                  dropout_179[0][0]
#                                                                  dropout_166[0][0]
#                                                                  dropout_167[0][0]
#                                                                  dropout_168[0][0]
#                                                                  dropout_169[0][0]
#                                                                  dropout_170[0][0]
#                                                                  dropout_171[0][0]
#                                                                  dropout_172[0][0]
#                                                                  dropout_173[0][0]
#                                                                  dropout_174[0][0]
#                                                                  dropout_175[0][0]
#                                                                  dropout_176[0][0]
#                                                                  dropout_177[0][0]
#                                                                  dropout_178[0][0]
# __________________________________________________________________________________________________
# reshape_150 (Reshape)           (None, 32)           0           mean_hin_aggregator_7[0][0]
# __________________________________________________________________________________________________
# reshape_151 (Reshape)           (None, 32)           0           mean_hin_aggregator_7[1][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 32)           0           reshape_150[0][0]
#                                                                  reshape_151[0][0]
# __________________________________________________________________________________________________
# link_embedding (LinkEmbedding)  (None, 1)            0           lambda[0][0]
#                                                                  lambda[1][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 1)            0           link_embedding[0][0]
# __________________________________________________________________________________________________
# reshape_152 (Reshape)           (None, 1)            0           activation[0][0]
# ==================================================================================================
# Total params: 72,960
# Trainable params: 72,960
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
init_train_metrics = model.evaluate(train_gen)
init_test_metrics = model.evaluate(test_gen)

print("\nTrain Set Metrics of the initial (untrained) model:")
for name, val in zip(model.metrics_names, init_train_metrics):
    print("\t{}: {:0.4f}".format(name, val))

print("\nTest Set Metrics of the initial (untrained) model:")
for name, val in zip(model.metrics_names, init_test_metrics):
    print("\t{}: {:0.4f}".format(name, val))
# Out:
# 2/5 [===========>..................] - ETA: 45s - loss: 1.3531 - accuracy: 0.5095

# %%
history = model.fit(train_gen,
                    epochs=epochs,
                    validation_data=test_gen,
                    use_multiprocessing=True,
                    verbose=2,
                    workers=num_workers)

# %%
plot_history(history)

# %%
train_metrics = model.evaluate(train_gen)
test_metrics = model.evaluate(test_gen)

print("\nTrain Set Metrics of the trained model:")
for name, val in zip(model.metrics_names, train_metrics):
    print("\t{}: {:0.4f}".format(name, val))

print("\nTest Set Metrics of the trained model:")
for name, val in zip(model.metrics_names, test_metrics):
    print("\t{}: {:0.4f}".format(name, val))
